# %%
import networkx as nx
import numpy as np
from datetime import datetime
from datetime import timedelta
import random
import time

# %%
G_0 = nx.Graph()

# %%
G_0.add_nodes_from([i for i in range(6)])

# %%
edge_list = [
    (0,1,8),
    (1,2,10),
    (2,0,6), 
    (0,3,5),
    (3,4,6),
    (3,5,9),
    (4,5,7),
    (5,0,4)
]

# %%
G_0.add_weighted_edges_from(edge_list)

# %%
edge_weight_dict = {e: G_0[e[0]][e[1]]['weight'] for e in G_0.edges}
edge_weight_dict
# Out:
# {(0, 1): 8,
#  (0, 2): 6,
#  (0, 3): 5,
#  (0, 5): 4,
#  (1, 2): 10,
#  (3, 4): 6,
#  (3, 5): 9,
#  (4, 5): 7}

# %%
pos=nx.spring_layout(G_0)
labels = {e: G_0[e[0]][e[1]]['weight'] for e in G_0.edges}
nx.draw(G_0,pos, with_labels=True)
nx.draw_networkx_edge_labels(G_0,pos, edge_labels=labels)
# Out:
# {(0, 1): Text(-0.20995694104048537, -0.5906430973728953, '8'),
#  (0, 2): Text(-0.42658723737561993, -0.5201359080943166, '6'),
#  (0, 3): Text(-0.037615929973589, 0.14120935839925958, '5'),
#  (0, 5): Text(0.16859330851417662, 0.06714425696772305, '4'),
#  (1, 2): Text(-0.48588171633006827, -0.8424954120670591, '10'),
#  (3, 4): Text(0.3172884078158913, 0.7753511550993359, '6'),
#  (3, 5): Text(0.28163984062662467, 0.47663720876713545, '9'),
#  (4, 5): Text(0.5234976463036569, 0.7012860536677995, '7')}

# %%
[n for n in G_0.neighbors(5)]
# Out:
# [3, 4, 0]

# %%
G = nx.DiGraph()

# %%
station_timestamp_list = [(0,datetime(2024, 1, 1, 9, 0)),
                                   (0,datetime(2024, 1, 1, 9, 22)),
                                   (0,datetime(2024, 1, 1, 9, 24)),
                                   (1,datetime(2024, 1, 1, 9, 8)),
                                   (2,datetime(2024, 1, 1, 9, 18)),
                                   (3,datetime(2024, 1, 1, 9, 5)),
                                   (4,datetime(2024, 1, 1, 9, 11)),
                                   (5,datetime(2024, 1, 1, 9, 18))]

# %%
edge_list  = [(station_timestamp_list[0],station_timestamp_list[1],22),
          (station_timestamp_list[1],station_timestamp_list[2],2),
              
          (station_timestamp_list[0],station_timestamp_list[5],5),
          (station_timestamp_list[5],station_timestamp_list[6],6),
          (station_timestamp_list[6],station_timestamp_list[7],7),
          (station_timestamp_list[7],station_timestamp_list[1],4),
              
          (station_timestamp_list[0],station_timestamp_list[3],8),
          (station_timestamp_list[3],station_timestamp_list[4],10),
          (station_timestamp_list[4],station_timestamp_list[2],6), 
]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates

# %%
G = nx.DiGraph()

# %%
for i in range(len(station_timestamp_list)):
    G.add_node(station_timestamp_list[i],pos=( matplotlib.dates.date2num(station_timestamp_list[i][1]),station_timestamp_list[i][0]) )

# %%
#G.add_nodes_from(station_timestamp_list)
G.add_weighted_edges_from(edge_list)

# %%
pos = nx.get_node_attributes(G,'pos')
pos
# Out:
# {(0, datetime.datetime(2024, 1, 1, 9, 0)): (19723.375, 0),
#  (0, datetime.datetime(2024, 1, 1, 9, 22)): (19723.390277777777, 0),
#  (0, datetime.datetime(2024, 1, 1, 9, 24)): (19723.391666666666, 0),
#  (1, datetime.datetime(2024, 1, 1, 9, 8)): (19723.380555555555, 1),
#  (2, datetime.datetime(2024, 1, 1, 9, 18)): (19723.3875, 2),
#  (3, datetime.datetime(2024, 1, 1, 9, 5)): (19723.378472222223, 3),
#  (4, datetime.datetime(2024, 1, 1, 9, 11)): (19723.38263888889, 4),
#  (5, datetime.datetime(2024, 1, 1, 9, 18)): (19723.3875, 5)}

# %%
demand_ = (0,7,datetime(2024, 1, 1, 8, 59))

# %%
def is_demand_finish(demand_,G):
    nearest_time = datetime(2025, 1, 1, 9, 0)
    nearest_stop = -1
    for node in G.nodes:
        if node[0] == demand_[0] and node[1]<= nearest_time and node[1] >= demand_[2]:
            nearest_stop = node[0]
            nearest_time = node[1]
    nearest_node = (nearest_stop,nearest_time)

    if nearest_stop == -1:
        return False
    
    for node in G.nodes:
        if node[0] == demand_[1] and nx.has_path(G,nearest_node,node):
            return True
    
    return False

# %%
is_demand_finish(demand_,G)
# Out:
# False

# %%
nx.draw(G, pos)

# %%
x_1 = np.array([[station_timestamp_list[0][1],station_timestamp_list[0][0]],
       [station_timestamp_list[1][1],station_timestamp_list[1][0]],
       [station_timestamp_list[2][1],station_timestamp_list[2][0]]])

x_2 = np.array([[station_timestamp_list[0][1],station_timestamp_list[0][0]],
       [station_timestamp_list[5][1],station_timestamp_list[5][0]],
       [station_timestamp_list[6][1],station_timestamp_list[6][0]],
       [station_timestamp_list[7][1],station_timestamp_list[7][0]],
       [station_timestamp_list[1][1],station_timestamp_list[1][0]]])

x_3 = np.array([[station_timestamp_list[0][1],station_timestamp_list[0][0]],
       [station_timestamp_list[3][1],station_timestamp_list[3][0]],
       [station_timestamp_list[4][1],station_timestamp_list[4][0]],
       [station_timestamp_list[2][1],station_timestamp_list[2][0]]])

# %%
station_timestamp_list = [(1,datetime(2024, 1, 1, 9, 0)),
                                   (1,datetime(2024, 1, 1, 9, 22)),
                                   (1,datetime(2024, 1, 1, 9, 24)),
                                   (2,datetime(2024, 1, 1, 9, 8)),
                                   (3,datetime(2024, 1, 1, 9, 18)),
                                   (4,datetime(2024, 1, 1, 9, 5)),
                                   (5,datetime(2024, 1, 1, 9, 11)),
                                   (6,datetime(2024, 1, 1, 9, 18))]

# %%
plt.plot(x_2[:,0],x_2[:,1])
plt.plot(x_3[:,0],x_3[:,1])

# %%
def current_set_of_actions(bus_stop, G):
    set_of_neighbors  = [neighbor_ for neighbor_ in G.neighbors(bus_stop)]
    
    dict_ = {}
    for neighbor_ in G.neighbors(bus_stop):
        time_ = G[bus_stop][neighbor_]['weight']
        dict_[neighbor_] = time_
    
    return dict_

# %%
from __future__ import division

import operator
from copy import deepcopy
from functools import reduce

from base import BaseState, BaseAction
from mcts import MCTS

# %%
class NaughtsAndCrossesState(BaseState):
    
    playerNames = {1: 'O', -1: 'X'}
    
    
    def __init__(self,G,bus_1,bus_2,demand_set):
        
        self.board = G
        self.currentPlayer = 1
        self.isTerminated = None
        self.reward = 0
        self.possibleActions = None
        self.winingPattern = None
        
        self.bus_1 = bus_1
        
        self.bus_2 = bus_2
        
        self.step = 0
        
        self.demand_set = demand_set
        
        self.advance_time = 0
        self.t_0 = datetime(2024, 1, 1, 9, 0)
        
    def get_current_player(self):
        return self.currentPlayer

    def get_possible_actions(self):
        
        if self.currentPlayer == 1 :
            if self.bus_1[-1][1] <= self.bus_2[-1][1]:
                bus_stop = self.bus_1[-1][0]
                possibleActions = [n for n in G_0.neighbors(bus_stop)]
            else:
                bus_stop = self.bus_2[-1][0]
                possibleActions = [n for n in G_0.neighbors(bus_stop)]
        else:#currentPlayer != 1
            possibleActions = [self.advance_time]
            
        return possibleActions

    def take_action(self, action):
        
        if self.currentPlayer == 1 : 
            newState = deepcopy(self)
            #change to newState
            new_bus_stop = action
            
            if self.bus_1[-1][1] <= self.bus_2[-1][1]:
                bus_stop = self.bus_1[-1][0]
                t_ = G_0[bus_stop][new_bus_stop]['weight']
                new_datatime = self.bus_1[-1][1] + timedelta(minutes=t_)
                newState.bus_1.append((new_bus_stop,new_datatime))
                
                newState.t_0 = self.bus_1[-1][1]
                
                if new_datatime <= self.bus_2[-1][1]:
                    newState.advance_time = t_
                else:
                    newState.advance_time = int((self.bus_2[-1][1] - self.bus_1[-1][1])/timedelta(minutes=1))
                
            else:
                bus_stop = self.bus_2[-1][0]
                t_ = G_0[bus_stop][new_bus_stop]['weight']
                new_datatime = self.bus_2[-1][1] + timedelta(minutes=t_)
                newState.bus_2.append((new_bus_stop,new_datatime))
                
                newState.t_0 = self.bus_2[-1][1]
                
                if new_datatime <= self.bus_1[-1][1]:
                    newState.advance_time = t_
                else:
                    newState.advance_time = int((self.bus_1[-1][1] - self.bus_2[-1][1])/timedelta(minutes=1))
                
            newState.board.add_node( (new_bus_stop,new_datatime), pos = (matplotlib.dates.date2num(new_datatime),new_bus_stop) )
            
            
            newState.board.add_weighted_edges_from([( (bus_stop,newState.t_0),(new_bus_stop,new_datatime),t_)])
            
            near_bus_stop = -1
            near_bus_stop_time = datetime(2024, 1, 1, 9, 0)
            for node in self.board.nodes:
                if node[0] == new_bus_stop and node[1]>=near_bus_stop_time and node[1]<new_datatime:
                    near_bus_stop = node[0]
                    near_bus_stop_time = node[1]
            
            delta_ = int((new_datatime - near_bus_stop_time)/timedelta(minutes=1))
            if near_bus_stop >= 0:
                newState.board.add_weighted_edges_from([( (near_bus_stop,near_bus_stop_time),(new_bus_stop,new_datatime),delta_)])
            
            reward_ = 0
            for demand_ in newState.demand_set:
                if is_demand_finish(demand_,newState.board):
                    newState.demand_set.remove(demand_)
                    reward_ = reward_+1
            newState.reward = newState.reward + reward_
            
            newState.step = newState.step + 1 
            
#             print('newState.step',newState.step)
#             print('reward_0',newState.reward)

            
        else:
            newState = deepcopy(self)
            ad_time = action
            
            r_ = 0
            for i in range(ad_time):
                delta_ = timedelta(minutes=i)
                original_ , destination_ = random.sample(range(0, 6), 2)
                demand_ = (original_,destination_,self.t_0 + delta_)
                if not is_demand_finish(demand_,self.board):
                    newState.demand_set.append( demand_ )
                    r_ = r_-1
            newState.reward = newState.reward + r_
            
            newState.step = newState.step + 1 
            
#             print('newState.step',newState.step)
#             print('reward_1',newState.reward)
            
        #change to currentPlayer of newState
        newState.currentPlayer = self.currentPlayer * -1
        return newState

    def is_terminal(self):
        if self.step > 5:
            return True
        else:
            return False

    def get_reward(self):
        return self.reward

# %%
# class Action(BaseAction):
#     def __init__(self, player, x, y):
#         self.player = player
#         self.x = x
#         self.y = y

#     def __str__(self):
#         return str((self.x, self.y))

#     def __repr__(self):
#         return str(self)

#     def __eq__(self, other):
#         return self.__class__ == other.__class__ and self.x == other.x and self.y == other.y and self.player == other.player

#     def __hash__(self):
#         return hash((self.x, self.y, self.player))

# %%
bus_1 = [(0,datetime(2024, 1, 1, 9, 0)),
        (3,datetime(2024, 1, 1, 9, 5)),
        (4,datetime(2024, 1, 1, 9, 11)),
        (5,datetime(2024, 1, 1, 9, 18)),
        (0,datetime(2024, 1, 1, 9, 22))]
        
bus_2 = [(0,datetime(2024, 1, 1, 9, 0)),
        (1,datetime(2024, 1, 1, 9, 8)),
        (2,datetime(2024, 1, 1, 9, 18)),
        (0,datetime(2024, 1, 1, 9, 24))]

demand_set = []
for i in range(22):
    original_ , destination_ = random.sample(range(0, 6), 2)
    demand_ = (original_,destination_,datetime(2024, 1, 1, 9, i))
    if not is_demand_finish(demand_,G):
        demand_set.append( demand_ )

# %%
def get_next_action(G,bus_1,bus_2,demand_set):
    initial_state = NaughtsAndCrossesState(deepcopy(G),bus_1,bus_2,demand_set)
    action = random.choice(initial_state.get_possible_actions())
    return action

# %%
t_1 = time.time()

set_len = []
for _ in range(100):
    
    action = get_next_action(G,bus_1,bus_2,demand_set)
    print('Step',_,'action',action)
    state_0 = NaughtsAndCrossesState(deepcopy(G),bus_1,bus_2,demand_set)

    state_1 = state_0.take_action(action)

    state_2 = state_1.take_action(action)

    G = deepcopy(state_2.board)
    bus_1 = deepcopy(state_2.bus_1)
    bus_2 = deepcopy(state_2.bus_2)
    demand_set = deepcopy(state_2.demand_set)
    set_len.append( len(demand_set) )
# Out:
# Step 0 action 3
# Step 1 action 1
# Step 2 action 4
# Step 3 action 2
# Step 4 action 5
# Step 5 action 4
# Step 6 action 0
# Step 7 action 3
# Step 8 action 1
# Step 9 action 0
# Step 10 action 0
# Step 11 action 1
# Step 12 action 1
# Step 13 action 2
# Step 14 action 2
# Step 15 action 1
# Step 16 action 1
# Step 17 action 2
# Step 18 action 0
# Step 19 action 0
# Step 20 action 1
# Step 21 action 5
# Step 22 action 3
# Step 23 action 0
# Step 24 action 4
# Step 25 action 3
# Step 26 action 5
# Step 27 action 5
# Step 28 action 4
# Step 29 action 4
# Step 30 action 3
# Step 31 action 3
# Step 32 action 0
# Step 33 action 5
# Step 34 action 2
# Step 35 action 1
# Step 36 action 0
# Step 37 action 5
# Step 38 action 0
# Step 39 action 2
# Step 40 action 5
# Step 41 action 0
# Step 42 action 0
# Step 43 action 3
# Step 44 action 0
# Step 45 action 1
# Step 46 action 5
# Step 47 action 2
# Step 48 action 0
# Step 49 action 5
# Step 50 action 0
# Step 51 action 0
# Step 52 action 2
# Step 53 action 2
# Step 54 action 1
# Step 55 action 1
# Step 56 action 2
# Step 57 action 2
# Step 58 action 1
# Step 59 action 0
# Step 60 action 1
# Step 61 action 0
# Step 62 action 2
# Step 63 action 5
# Step 64 action 0
# Step 65 action 2
# Step 66 action 0
# Step 67 action 1
# Step 68 action 3
# Step 69 action 4
# Step 70 action 0
# Step 71 action 5
# Step 72 action 1
# Step 73 action 3
# Step 74 action 0
# Step 75 action 5
# Step 76 action 3
# Step 77 action 4
# Step 78 action 5
# Step 79 action 5
# Step 80 action 0
# Step 81 action 4
# Step 82 action 5
# Step 83 action 3
# Step 84 action 3
# Step 85 action 5
# Step 86 action 5
# Step 87 action 0
# Step 88 action 0
# Step 89 action 5
# Step 90 action 2
# Step 91 action 4
# Step 92 action 1
# Step 93 action 5
# Step 94 action 0
# Step 95 action 3
# Step 96 action 2
# Step 97 action 4
# Step 98 action 0
# Step 99 action 3

# %%
bus_1 #2 0 1 0 3
# Out:
# [(0, datetime.datetime(2024, 1, 1, 9, 0)),
#  (3, datetime.datetime(2024, 1, 1, 9, 5)),
#  (4, datetime.datetime(2024, 1, 1, 9, 11)),
#  (5, datetime.datetime(2024, 1, 1, 9, 18)),
#  (0, datetime.datetime(2024, 1, 1, 9, 22)),
#  (3, datetime.datetime(2024, 1, 1, 9, 27)),
#  (4, datetime.datetime(2024, 1, 1, 9, 33)),
#  (5, datetime.datetime(2024, 1, 1, 9, 40)),
#  (4, datetime.datetime(2024, 1, 1, 9, 47)),
#  (3, datetime.datetime(2024, 1, 1, 9, 53)),
#  (0, datetime.datetime(2024, 1, 1, 9, 58)),
#  (1, datetime.datetime(2024, 1, 1, 10, 6)),
#  (2, datetime.datetime(2024, 1, 1, 10, 16)),
#  (1, datetime.datetime(2024, 1, 1, 10, 26)),
#  (2, datetime.datetime(2024, 1, 1, 10, 36)),
#  (0, datetime.datetime(2024, 1, 1, 10, 42)),
#  (5, datetime.datetime(2024, 1, 1, 10, 46)),
#  (3, datetime.datetime(2024, 1, 1, 10, 55)),
#  (4, datetime.datetime(2024, 1, 1, 11, 1)),
#  (5, datetime.datetime(2024, 1, 1, 11, 8)),
#  (4, datetime.datetime(2024, 1, 1, 11, 15)),
#  (3, datetime.datetime(2024, 1, 1, 11, 21)),
#  (0, datetime.datetime(2024, 1, 1, 11, 26)),
#  (2, datetime.datetime(2024, 1, 1, 11, 32)),
#  (1, datetime.datetime(2024, 1, 1, 11, 42)),
#  (2, datetime.datetime(2024, 1, 1, 11, 52)),
#  (0, datetime.datetime(2024, 1, 1, 11, 58)),
#  (1, datetime.datetime(2024, 1, 1, 12, 6)),
#  (2, datetime.datetime(2024, 1, 1, 12, 16)),
#  (0, datetime.datetime(2024, 1, 1, 12, 22)),
#  (2, datetime.datetime(2024, 1, 1, 12, 28)),
#  (1, datetime.datetime(2024, 1, 1, 12, 38)),
#  (2, datetime.datetime(2024, 1, 1, 12, 48)),
#  (0, datetime.datetime(2024, 1, 1, 12, 54)),
#  (1, datetime.datetime(2024, 1, 1, 13, 2)),
#  (2, datetime.datetime(2024, 1, 1, 13, 12)),
#  (0, datetime.datetime(2024, 1, 1, 13, 18)),
#  (3, datetime.datetime(2024, 1, 1, 13, 23)),
#  (4, datetime.datetime(2024, 1, 1, 13, 29)),
#  (5, datetime.datetime(2024, 1, 1, 13, 36)),
#  (3, datetime.datetime(2024, 1, 1, 13, 45)),
#  (5, datetime.datetime(2024, 1, 1, 13, 54)),
#  (4, datetime.datetime(2024, 1, 1, 14, 1)),
#  (5, datetime.datetime(2024, 1, 1, 14, 8)),
#  (4, datetime.datetime(2024, 1, 1, 14, 15)),
#  (3, datetime.datetime(2024, 1, 1, 14, 21)),
#  (5, datetime.datetime(2024, 1, 1, 14, 30)),
#  (0, datetime.datetime(2024, 1, 1, 14, 34)),
#  (5, datetime.datetime(2024, 1, 1, 14, 38)),
#  (4, datetime.datetime(2024, 1, 1, 14, 45)),
#  (5, datetime.datetime(2024, 1, 1, 14, 52)),
#  (3, datetime.datetime(2024, 1, 1, 15, 1)),
#  (4, datetime.datetime(2024, 1, 1, 15, 7)),
#  (3, datetime.datetime(2024, 1, 1, 15, 13))]

# %%
bus_2 #1 2 0 2 1 0
# Out:
# [(0, datetime.datetime(2024, 1, 1, 9, 0)),
#  (1, datetime.datetime(2024, 1, 1, 9, 8)),
#  (2, datetime.datetime(2024, 1, 1, 9, 18)),
#  (0, datetime.datetime(2024, 1, 1, 9, 24)),
#  (1, datetime.datetime(2024, 1, 1, 9, 32)),
#  (2, datetime.datetime(2024, 1, 1, 9, 42)),
#  (0, datetime.datetime(2024, 1, 1, 9, 48)),
#  (1, datetime.datetime(2024, 1, 1, 9, 56)),
#  (0, datetime.datetime(2024, 1, 1, 10, 4)),
#  (1, datetime.datetime(2024, 1, 1, 10, 12)),
#  (2, datetime.datetime(2024, 1, 1, 10, 22)),
#  (1, datetime.datetime(2024, 1, 1, 10, 32)),
#  (0, datetime.datetime(2024, 1, 1, 10, 40)),
#  (1, datetime.datetime(2024, 1, 1, 10, 48)),
#  (0, datetime.datetime(2024, 1, 1, 10, 56)),
#  (3, datetime.datetime(2024, 1, 1, 11, 1)),
#  (5, datetime.datetime(2024, 1, 1, 11, 10)),
#  (4, datetime.datetime(2024, 1, 1, 11, 17)),
#  (3, datetime.datetime(2024, 1, 1, 11, 23)),
#  (5, datetime.datetime(2024, 1, 1, 11, 32)),
#  (0, datetime.datetime(2024, 1, 1, 11, 36)),
#  (5, datetime.datetime(2024, 1, 1, 11, 40)),
#  (0, datetime.datetime(2024, 1, 1, 11, 44)),
#  (5, datetime.datetime(2024, 1, 1, 11, 48)),
#  (0, datetime.datetime(2024, 1, 1, 11, 52)),
#  (3, datetime.datetime(2024, 1, 1, 11, 57)),
#  (0, datetime.datetime(2024, 1, 1, 12, 2)),
#  (5, datetime.datetime(2024, 1, 1, 12, 6)),
#  (0, datetime.datetime(2024, 1, 1, 12, 10)),
#  (5, datetime.datetime(2024, 1, 1, 12, 14)),
#  (0, datetime.datetime(2024, 1, 1, 12, 18)),
#  (2, datetime.datetime(2024, 1, 1, 12, 24)),
#  (1, datetime.datetime(2024, 1, 1, 12, 34)),
#  (2, datetime.datetime(2024, 1, 1, 12, 44)),
#  (1, datetime.datetime(2024, 1, 1, 12, 54)),
#  (0, datetime.datetime(2024, 1, 1, 13, 2)),
#  (5, datetime.datetime(2024, 1, 1, 13, 6)),
#  (0, datetime.datetime(2024, 1, 1, 13, 10)),
#  (2, datetime.datetime(2024, 1, 1, 13, 16)),
#  (1, datetime.datetime(2024, 1, 1, 13, 26)),
#  (0, datetime.datetime(2024, 1, 1, 13, 34)),
#  (1, datetime.datetime(2024, 1, 1, 13, 42)),
#  (0, datetime.datetime(2024, 1, 1, 13, 50)),
#  (3, datetime.datetime(2024, 1, 1, 13, 55)),
#  (5, datetime.datetime(2024, 1, 1, 14, 4)),
#  (0, datetime.datetime(2024, 1, 1, 14, 8)),
#  (5, datetime.datetime(2024, 1, 1, 14, 12)),
#  (3, datetime.datetime(2024, 1, 1, 14, 21)),
#  (5, datetime.datetime(2024, 1, 1, 14, 30)),
#  (0, datetime.datetime(2024, 1, 1, 14, 34)),
#  (2, datetime.datetime(2024, 1, 1, 14, 40)),
#  (1, datetime.datetime(2024, 1, 1, 14, 50)),
#  (0, datetime.datetime(2024, 1, 1, 14, 58)),
#  (2, datetime.datetime(2024, 1, 1, 15, 4)),
#  (0, datetime.datetime(2024, 1, 1, 15, 10))]

# %%
print( time.time() - t_1)
# Out:
# 0.8666212558746338

# %%
np.array( set_len )
# Out:
# array([16, 15, 18, 17, 20, 24, 23, 25, 23, 18, 18, 18, 19, 18, 19, 20, 21,
#        23, 22, 22, 23, 24, 21, 19, 19, 19, 22, 25, 27, 29, 31, 34, 30, 32,
#        32, 25, 24, 29, 28, 29, 34, 34, 30, 31, 31, 31, 33, 34, 33, 38, 37,
#        36, 36, 38, 39, 40, 41, 43, 43, 43, 44, 44, 46, 51, 51, 53, 52, 53,
#        49, 39, 34, 33, 31, 32, 32, 37, 39, 42, 44, 47, 41, 38, 43, 43, 46,
#        50, 55, 53, 53, 57, 50, 47, 39, 40, 36, 38, 35, 38, 38, 40])

# %%
len(bus_1)
# Out:
# 54

# %%
len(bus_2)
# Out:
# 55
